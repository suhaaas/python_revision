# %%
#Modules

# %%
#Iterators - to support operations that uses python, for big data streams

# %%
colors = ["red","blue","green"]

# %%
iterator = iter(colors)

# %%
print(next(iterator))
print(next(iterator))
print(next(iterator))
# Out:
# blue
# green
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[4], line 3
#       1 print(next(iterator))
#       2 print(next(iterator))
# ----> 3 print(next(iterator))
#
# StopIteration:

# %%
#Scopes -Local,Enclosing Scope,Global,Built-In
