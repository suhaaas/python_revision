# %%
#open a file
file = open("/Users/suhaskishore/Downloads/example.rtf","r")

# %%
file
# Out:
# <_io.TextIOWrapper name='/Users/suhaskishore/Downloads/example.rtf' mode='r' encoding='UTF-8'>

# %%
#read data from file
file = open("/Users/suhaskishore/Downloads/example.rtf","r")
data = file.read()
print(data)
file.close()
# Out:
# {\rtf1\ansi\ansicpg1252\cocoartf2822
# \cocoatextscaling0\cocoaplatform0{\fonttbl\f0\fswiss\fcharset0 Helvetica;}
# {\colortbl;\red255\green255\blue255;}
# {\*\expandedcolortbl;;}
# \margl1440\margr1440\vieww11520\viewh8400\viewkind0
# \pard\tx720\tx1440\tx2160\tx2880\tx3600\tx4320\tx5040\tx5760\tx6480\tx7200\tx7920\tx8640\pardirnatural\partightenfactor0
#
# \f0\fs24 \cf0 His. This is my first time I am using this and I am very excited}

# %%
#read one string at a time
file = open("/Users/suhaskishore/Downloads/example.rtf","r")
line = file.readline
while line:
    print(line)
    line = file.readline()
file.close()
# Out:
# <built-in method readline of _io.TextIOWrapper object at 0x111b11b60>
# {\rtf1\ansi\ansicpg1252\cocoartf2822
#
# \cocoatextscaling0\cocoaplatform0{\fonttbl\f0\fswiss\fcharset0 Helvetica;}
#
# {\colortbl;\red255\green255\blue255;}
#
# {\*\expandedcolortbl;;}
#
# \margl1440\margr1440\vieww11520\viewh8400\viewkind0
#
# \pard\tx720\tx1440\tx2160\tx2880\tx3600\tx4320\tx5040\tx5760\tx6480\tx7200\tx7920\tx8640\pardirnatural\partightenfactor0
#
#
#
# \f0\fs24 \cf0 His. This is my first time I am using this and I am very excited}

# %%
#write string to a file
file = open("/Users/suhaskishore/Downloads/example.rtf","w")
file.write("Hello, world\n")
file.close()

# %%
#close a file
file = open("/Users/suhaskishore/Downloads/example.rtf","r")
data = file.read()
file.close()

# %%
#check if file exists
import os.path

# %%
if os.path.isfile("/Users/suhaskishore/Downloads/example.rtf"):
    print("the file exists")
else:
    print("does not exist")
# Out:
# the file exists

# %%
#to get current working directory
cwd = os.getcwd()
print(cwd)
# Out:
# /Users/suhaskishore/python_revision

# %%
#list of files in a directory
files = os.listdir("/Users/suhaskishore/python_revision")
print(files)
# Out:
# ['FileHandling.ipynb', 'Lists.ipynb', '.ipynb_checkpoints', 'strings.py', 'strings1.ipynb']
