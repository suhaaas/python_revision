# %%
#trim and cleanup
s = "  suhas  "
print(s.strip())
print(s.lstrip())
print(s.rstrip())
# Out:
# suhas
# suhas
#   suhas

# %%
#searching
s1 = 'suhas'
print(s.find('u'))
# Out:
# 3

# %%
#replace
str = 'python'
new_str = str.replace('t','T')
print(new_str)
# Out:
# pyThon

# %%
#length of string
str = 'python'
print(len(str))
# Out:
# 6

# %%
#changing case
str = "python"
print(str.upper())
str1 = 'PYTHON'
print(str.lower())
# Out:
# PYTHON
# python

# %%
#splitting
str = "python-scriptting-language"
print(str.split('-'))
# Out:
# ['python', 'scriptting', 'language']

# %%
#split and join
str = "one,two,three"
new_str = str.split(',')
print(str)
print(new_str)
# Out:
# one,two,three
# ['one', 'two', 'three']

# %%
#string slicing
str = "masters"
str[0:3]
str[2:]
str[3:]
str[::-1]
# Out:
# 'sretsam'

# %%
str = "Pyhton"
print(str[-4:-1]) #0,1,2,3,4,5 & -6,-5,-4,-3,-2,-1
# Out:
# hto

# %%
#replacing string elements
str = 'python'
str[0] = 'm'
print(new_str)
#TypeError: 'str' object does not support item assignment - string is immuatable and we cant modify
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 3
#       1 #replacing string elements
#       2 str = 'python'
# ----> 3 str[0] = 'm'
#       4 print(new_str)
#
# TypeError: 'str' object does not support item assignment

# %%
#reverse a string
def reverse_string(s):
    rev = ""
    for i in s:
        rev = i + rev
    return rev

# %%
print(reverse_string('table'))
# Out:
# elbat
